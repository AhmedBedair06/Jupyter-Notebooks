# %% [markdown]
# # Project: cleanning - [Candy Dataset]
# ### this notebook is for educational purpose . in this notebook we will do some cleaning
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">wrangling</a></li>
#
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# ### Dataset Description
#
# > i will go through candy data 2017 , this data has :
# - Internal_ID
# - Q1-Going Out?: Are you actually going trick or treating yourself? "has values `Yes or No`"
# - Q2-Gender: It has four different options, `Femal ,Male ,Other ,I'd rather not say`
# - Q3-Age: Numerical field
# - Q4-Country: Text Field, but users have written their own version of the names. Example, for America, there are entries such as USA, us, US, America so we should consider that while cleanning
# - Q5-State/Province: Text Field, but users have written their own version of the names. Same as the country data.
# - Q6-Joy Or Despair: All kinds of chocolate bars are the questions with three distinct options to choose from (Joy, Meh, Despair).
# - Q7-Joy Other: Text Field to write items not included above that give you JOY. Lots of missing values.
# - Q8-Despair Other: Text Field ti write items not included above that give you DESPAIR. Lots of missing values.
# - Q9-Other Comments: Text Field. Lots of missing values.
# - Q10-Dress: Binary field. Missing values present
# - Unnamed: 113
# - Q11-Day: Binary Answer Field. Missing values present

# %% [markdown]
# # 1- Import packages and load data

# %%
! pip3 install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\mancr\anaconda3\lib\site-packages (0.18.0)

# %%
import numpy as np
import pandas as pd
from fuzzywuzzy import process

candy = pd.read_excel('candyhierarchy2017.xlsx')
# Out:
# C:\Users\mancr\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# C:\Users\mancr\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling

# %% [markdown]
# # 2- General Properties

# %%
#Show first 5 rows of data
candy.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Q6 | Any full-sized candy bar Q6 | Black Jacks  ... Q8: DESPAIR OTHER  \
# 0                           NaN              NaN  ...               NaN
# 1                           JOY              MEH  ...               NaN
# 2                           NaN              NaN  ...               NaN
# 3                           JOY              MEH  ...               NaN
# 4                           JOY          DESPAIR  ...               NaN
#
#                                   Q9: OTHER COMMENTS      Q10: DRESS  \
# 0                                                NaN             NaN
# 1  Bottom line is Twix is really the only candy w...  White and gold
# 2                                                NaN             NaN
# 3                             Raisins can go to hell  White and gold
# 4                                                NaN  White and gold
#
#   Unnamed: 113 Q11: DAY Q12: MEDIA [Daily Dish] Q12: MEDIA [Science]  \
# 0          NaN      NaN                     NaN                  NaN
# 1          NaN   Sunday                     NaN                  1.0
# 2          NaN      NaN                     NaN                  NaN
# 3          NaN   Sunday                     NaN                  1.0
# 4          NaN   Friday                     NaN                  1.0
#
#   Q12: MEDIA [ESPN] Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 0               NaN                NaN                      NaN
# 1               NaN                NaN                 (84, 25)
# 2               NaN                NaN                      NaN
# 3               NaN                NaN                 (75, 23)
# 4               NaN                NaN                 (70, 10)
#
# [5 rows x 120 columns]

# %%
#Show number of rows and columns in data
candy.shape
# Out:
# (2460, 120)

# %%
#Show number of missing values in each column
pd.set_option('display.max_rows', 1000)
candy.isna().sum()
# Out:
# Internal ID                                                                                  0
# Q1: GOING OUT?                                                                             110
# Q2: GENDER                                                                                  41
# Q3: AGE                                                                                     84
# Q4: COUNTRY                                                                                 64
# Q5: STATE, PROVINCE, COUNTY, ETC                                                           100
# Q6 | 100 Grand Bar                                                                         747
# Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)     734
# Q6 | Any full-sized candy bar                                                              672
# Q6 | Black Jacks                                                                           958
# Q6 | Bonkers (the candy)                                                                   992
# Q6 | Bonkers (the board game)                                                             1006
# Q6 | Bottle Caps                                                                           765
# Q6 | Box'o'Raisins                                                                         688
# Q6 | Broken glow stick                                                                     706
# Q6 | Butterfinger                                                                          682
# Q6 | Cadbury Creme Eggs                                                                    683
# Q6 | Candy Corn                                                                            678
# Q6 | Candy that is clearly just the stuff given out for free at restaurants                691
# Q6 | Caramellos                                                                            752
# Q6 | Cash, or other forms of legal tender                                                  680
# Q6 | Chardonnay                                                                            743
# Q6 | Chick-o-Sticks (we don’t know what that is)                                           946
# Q6 | Chiclets                                                                              711
# Q6 | Coffee Crisp                                                                          853
# Q6 | Creepy Religious comics/Chick Tracts                                                  704
# Q6 | Dental paraphenalia                                                                   692
# Q6 | Dots                                                                                  729
# Q6 | Dove Bars                                                                             702
# Q6 | Fuzzy Peaches                                                                         823
# Q6 | Generic Brand Acetaminophen                                                           731
# Q6 | Glow sticks                                                                           697
# Q6 | Goo Goo Clusters                                                                      879
# Q6 | Good N' Plenty                                                                        734
# Q6 | Gum from baseball cards                                                               716
# Q6 | Gummy Bears straight up                                                               697
# Q6 | Hard Candy                                                                            695
# Q6 | Healthy Fruit                                                                         694
# Q6 | Heath Bar                                                                             712
# Q6 | Hershey's Dark Chocolate                                                              673
# Q6 | Hershey’s Milk Chocolate                                                              672
# Q6 | Hershey's Kisses                                                                      678
# Q6 | Hugs (actual physical hugs)                                                           713
# Q6 | Jolly Rancher (bad flavor)                                                            694
# Q6 | Jolly Ranchers (good flavor)                                                          695
# Q6 | JoyJoy (Mit Iodine!)                                                                 1026
# Q6 | Junior Mints                                                                          698
# Q6 | Senior Mints                                                                          942
# Q6 | Kale smoothie                                                                         744
# Q6 | Kinder Happy Hippo                                                                    945
# Q6 | Kit Kat                                                                               674
# Q6 | LaffyTaffy                                                                            736
# Q6 | LemonHeads                                                                            730
# Q6 | Licorice (not black)                                                                  686
# Q6 | Licorice (yes black)                                                                  685
# Q6 | Lindt Truffle                                                                         718
# Q6 | Lollipops                                                                             691
# Q6 | Mars                                                                                  725
# Q6 | Maynards                                                                             1024
# Q6 | Mike and Ike                                                                          729
# Q6 | Milk Duds                                                                             693
# Q6 | Milky Way                                                                             688
# Q6 | Regular M&Ms                                                                          675
# Q6 | Peanut M&M’s                                                                          671
# Q6 | Blue M&M's                                                                            727
# Q6 | Red M&M's                                                                             729
# Q6 | Green Party M&M's                                                                     764
# Q6 | Independent M&M's                                                                     813
# Q6 | Abstained from M&M'ing.                                                               942
# Q6 | Minibags of chips                                                                     724
# Q6 | Mint Kisses                                                                           776
# Q6 | Mint Juleps                                                                           811
# Q6 | Mr. Goodbar                                                                           740
# Q6 | Necco Wafers                                                                          744
# Q6 | Nerds                                                                                 723
# Q6 | Nestle Crunch                                                                         698
# Q6 | Now'n'Laters                                                                          817
# Q6 | Peeps                                                                                 710
# Q6 | Pencils                                                                               709
# Q6 | Pixy Stix                                                                             722
# Q6 | Real Housewives of Orange County Season 9 Blue-Ray                                    753
# Q6 | Reese’s Peanut Butter Cups                                                            679
# Q6 | Reese's Pieces                                                                        691
# Q6 | Reggie Jackson Bar                                                                   1014
# Q6 | Rolos                                                                                 714
# Q6 | Sandwich-sized bags filled with BooBerry Crunch                                       776
# Q6 | Skittles                                                                              706
# Q6 | Smarties (American)                                                                   725
# Q6 | Smarties (Commonwealth)                                                               901
# Q6 | Snickers                                                                              690
# Q6 | Sourpatch Kids (i.e. abominations of nature)                                          738
# Q6 | Spotted Dick                                                                          882
# Q6 | Starburst                                                                             693
# Q6 | Sweet Tarts                                                                           708
# Q6 | Swedish Fish                                                                          715
# Q6 | Sweetums (a friend to diabetes)                                                      1002
# Q6 | Take 5                                                                                917
# Q6 | Tic Tacs                                                                              714
# Q6 | Those odd marshmallow circus peanut things                                            736
# Q6 | Three Musketeers                                                                      708
# Q6 | Tolberone something or other                                                          706
# Q6 | Trail Mix                                                                             708
# Q6 | Twix                                                                                  690
# Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein                792
# Q6 | Vicodin                                                                               789
# Q6 | Whatchamacallit Bars                                                                  823
# Q6 | White Bread                                                                           757
# Q6 | Whole Wheat anything                                                                  747
# Q6 | York Peppermint Patties                                                               705
# Q7: JOY OTHER                                                                             1549
# Q8: DESPAIR OTHER                                                                         1743
# Q9: OTHER COMMENTS                                                                        2074
# Q10: DRESS                                                                                 744
# Unnamed: 113                                                                              2451
# Q11: DAY                                                                                   725
# Q12: MEDIA [Daily Dish]                                                                   2375
# Q12: MEDIA [Science]                                                                      1098
# Q12: MEDIA [ESPN]                                                                         2361
# Q12: MEDIA [Yahoo]                                                                        2393
# Click Coordinates (x, y)                                                                   855
# dtype: int64

# %%
#Check for duplicates
candy.duplicated().sum()
# Out:
# 0

# %%
#Show datatypes of columns
candy.dtypes
# Out:
# Internal ID                                                                                 int64
# Q1: GOING OUT?                                                                             object
# Q2: GENDER                                                                                 object
# Q3: AGE                                                                                    object
# Q4: COUNTRY                                                                                object
# Q5: STATE, PROVINCE, COUNTY, ETC                                                           object
# Q6 | 100 Grand Bar                                                                         object
# Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)     object
# Q6 | Any full-sized candy bar                                                              object
# Q6 | Black Jacks                                                                           object
# Q6 | Bonkers (the candy)                                                                   object
# Q6 | Bonkers (the board game)                                                              object
# Q6 | Bottle Caps                                                                           object
# Q6 | Box'o'Raisins                                                                         object
# Q6 | Broken glow stick                                                                     object
# Q6 | Butterfinger                                                                          object
# Q6 | Cadbury Creme Eggs                                                                    object
# Q6 | Candy Corn                                                                            object
# Q6 | Candy that is clearly just the stuff given out for free at restaurants                object
# Q6 | Caramellos                                                                            object
# Q6 | Cash, or other forms of legal tender                                                  object
# Q6 | Chardonnay                                                                            object
# Q6 | Chick-o-Sticks (we don’t know what that is)                                           object
# Q6 | Chiclets                                                                              object
# Q6 | Coffee Crisp                                                                          object
# Q6 | Creepy Religious comics/Chick Tracts                                                  object
# Q6 | Dental paraphenalia                                                                   object
# Q6 | Dots                                                                                  object
# Q6 | Dove Bars                                                                             object
# Q6 | Fuzzy Peaches                                                                         object
# Q6 | Generic Brand Acetaminophen                                                           object
# Q6 | Glow sticks                                                                           object
# Q6 | Goo Goo Clusters                                                                      object
# Q6 | Good N' Plenty                                                                        object
# Q6 | Gum from baseball cards                                                               object
# Q6 | Gummy Bears straight up                                                               object
# Q6 | Hard Candy                                                                            object
# Q6 | Healthy Fruit                                                                         object
# Q6 | Heath Bar                                                                             object
# Q6 | Hershey's Dark Chocolate                                                              object
# Q6 | Hershey’s Milk Chocolate                                                              object
# Q6 | Hershey's Kisses                                                                      object
# Q6 | Hugs (actual physical hugs)                                                           object
# Q6 | Jolly Rancher (bad flavor)                                                            object
# Q6 | Jolly Ranchers (good flavor)                                                          object
# Q6 | JoyJoy (Mit Iodine!)                                                                  object
# Q6 | Junior Mints                                                                          object
# Q6 | Senior Mints                                                                          object
# Q6 | Kale smoothie                                                                         object
# Q6 | Kinder Happy Hippo                                                                    object
# Q6 | Kit Kat                                                                               object
# Q6 | LaffyTaffy                                                                            object
# Q6 | LemonHeads                                                                            object
# Q6 | Licorice (not black)                                                                  object
# Q6 | Licorice (yes black)                                                                  object
# Q6 | Lindt Truffle                                                                         object
# Q6 | Lollipops                                                                             object
# Q6 | Mars                                                                                  object
# Q6 | Maynards                                                                              object
# Q6 | Mike and Ike                                                                          object
# Q6 | Milk Duds                                                                             object
# Q6 | Milky Way                                                                             object
# Q6 | Regular M&Ms                                                                          object
# Q6 | Peanut M&M’s                                                                          object
# Q6 | Blue M&M's                                                                            object
# Q6 | Red M&M's                                                                             object
# Q6 | Green Party M&M's                                                                     object
# Q6 | Independent M&M's                                                                     object
# Q6 | Abstained from M&M'ing.                                                               object
# Q6 | Minibags of chips                                                                     object
# Q6 | Mint Kisses                                                                           object
# Q6 | Mint Juleps                                                                           object
# Q6 | Mr. Goodbar                                                                           object
# Q6 | Necco Wafers                                                                          object
# Q6 | Nerds                                                                                 object
# Q6 | Nestle Crunch                                                                         object
# Q6 | Now'n'Laters                                                                          object
# Q6 | Peeps                                                                                 object
# Q6 | Pencils                                                                               object
# Q6 | Pixy Stix                                                                             object
# Q6 | Real Housewives of Orange County Season 9 Blue-Ray                                    object
# Q6 | Reese’s Peanut Butter Cups                                                            object
# Q6 | Reese's Pieces                                                                        object
# Q6 | Reggie Jackson Bar                                                                    object
# Q6 | Rolos                                                                                 object
# Q6 | Sandwich-sized bags filled with BooBerry Crunch                                       object
# Q6 | Skittles                                                                              object
# Q6 | Smarties (American)                                                                   object
# Q6 | Smarties (Commonwealth)                                                               object
# Q6 | Snickers                                                                              object
# Q6 | Sourpatch Kids (i.e. abominations of nature)                                          object
# Q6 | Spotted Dick                                                                          object
# Q6 | Starburst                                                                             object
# Q6 | Sweet Tarts                                                                           object
# Q6 | Swedish Fish                                                                          object
# Q6 | Sweetums (a friend to diabetes)                                                       object
# Q6 | Take 5                                                                                object
# Q6 | Tic Tacs                                                                              object
# Q6 | Those odd marshmallow circus peanut things                                            object
# Q6 | Three Musketeers                                                                      object
# Q6 | Tolberone something or other                                                          object
# Q6 | Trail Mix                                                                             object
# Q6 | Twix                                                                                  object
# Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein                object
# Q6 | Vicodin                                                                               object
# Q6 | Whatchamacallit Bars                                                                  object
# Q6 | White Bread                                                                           object
# Q6 | Whole Wheat anything                                                                  object
# Q6 | York Peppermint Patties                                                               object
# Q7: JOY OTHER                                                                              object
# Q8: DESPAIR OTHER                                                                          object
# Q9: OTHER COMMENTS                                                                         object
# Q10: DRESS                                                                                 object
# Unnamed: 113                                                                               object
# Q11: DAY                                                                                   object
# Q12: MEDIA [Daily Dish]                                                                   float64
# Q12: MEDIA [Science]                                                                      float64
# Q12: MEDIA [ESPN]                                                                         float64
# Q12: MEDIA [Yahoo]                                                                        float64
# Click Coordinates (x, y)                                                                   object
# dtype: object

# %%
#Show properties of Age since it is the only numeric column
candy['Q3: AGE'].describe()
# Out:
# count     2376
# unique     106
# top         40
# freq        92
# Name: Q3: AGE, dtype: int64

# %% [markdown]
# # 3- Data Wrangling summary
# -The dataset contains multiple useless columns such as Internal Id,Other Comments,Unnamed,Click Coordinates and all the media columns.<br>
# -The country and state/province column are inconsistent due to free text input.<br>
# -Most columns if not all of them are of object datatype while they should be of other types. For example the age column should be integer,gender should be categorical,country should be string,etc....<br>
# -There is a lot of missing data in all of the columns,which means that simply removing the missing values would not work.<br>
# -There are no duplicated rows in the dataset.<br>
# -Running .describe() on the Age column gave no benefit because the column is of object datatype.<br>

# %% [markdown]
# # cleaning

# %% [markdown]
# ### 4- drop all the useless columns and  rows with too much NaN ,

# %%
#Drop columns with too much missing values and no real benefit to the data.
useless_cols = ['Internal ID','Q5: STATE, PROVINCE, COUNTY, ETC','Q7: JOY OTHER','Q8: DESPAIR OTHER','Q9: OTHER COMMENTS','Unnamed: 113','Q12: MEDIA [Daily Dish]','Q12: MEDIA [Science]','Q12: MEDIA [ESPN]','Q12: MEDIA [Yahoo]','Click Coordinates (x, y)']
candy.drop(useless_cols,axis=1,inplace=True)
candy.head()
# Out:
#   Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY Q6 | 100 Grand Bar  \
# 0            NaN        NaN     NaN         NaN                NaN
# 1             No       Male      44        USA                 MEH
# 2            NaN       Male      49         USA                NaN
# 3             No       Male      40          us                MEH
# 4             No       Male      23         usa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 0                           NaN              NaN                      NaN
# 1                           JOY              MEH                  DESPAIR
# 2                           NaN              NaN                      NaN
# 3                           JOY              MEH                      MEH
# 4                           JOY          DESPAIR                      MEH
#
#   Q6 | Bonkers (the board game)  ... Q6 | Trail Mix Q6 | Twix  \
# 0                           NaN  ...            NaN       NaN
# 1                       DESPAIR  ...        DESPAIR       JOY
# 2                           NaN  ...            NaN       NaN
# 3                       DESPAIR  ...            MEH       JOY
# 4                       DESPAIR  ...        DESPAIR       JOY
#
#   Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                                MEH
#
#   Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 0          NaN                       NaN              NaN
# 1      DESPAIR                   DESPAIR          DESPAIR
# 2          NaN                       NaN              NaN
# 3          JOY                       JOY          DESPAIR
# 4          JOY                       JOY          DESPAIR
#
#   Q6 | Whole Wheat anything Q6 | York Peppermint Patties      Q10: DRESS  \
# 0                       NaN                          NaN             NaN
# 1                   DESPAIR                      DESPAIR  White and gold
# 2                       NaN                          NaN             NaN
# 3                   DESPAIR                      DESPAIR  White and gold
# 4                   DESPAIR                          JOY  White and gold
#
#   Q11: DAY
# 0      NaN
# 1   Sunday
# 2      NaN
# 3   Sunday
# 4   Friday
#
# [5 rows x 109 columns]

# %%
#Rename columns by using [4:] to remove the Q# parts and .strip to remove white space and .title to handle columns with all capital letters
candy.columns = candy.columns.str[4:].str.strip().str.title()
candy.head()
# Out:
#   Going Out? Gender  Age Country 100 Grand Bar  \
# 0        NaN    NaN  NaN     NaN           NaN
# 1         No   Male   44    USA            MEH
# 2        NaN   Male   49     USA           NaN
# 3         No   Male   40      us           MEH
# 4         No   Male   23     usa           JOY
#
#   Anonymous Brown Globs That Come In Black And Orange Wrappers\t(A.K.A. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any Full-Sized Candy Bar Black Jacks Bonkers (The Candy)  \
# 0                      NaN         NaN                 NaN
# 1                      JOY         MEH             DESPAIR
# 2                      NaN         NaN                 NaN
# 3                      JOY         MEH                 MEH
# 4                      JOY     DESPAIR                 MEH
#
#   Bonkers (The Board Game)  ... Trail Mix Twix  \
# 0                      NaN  ...       NaN  NaN
# 1                  DESPAIR  ...   DESPAIR  JOY
# 2                      NaN  ...       NaN  NaN
# 3                  DESPAIR  ...       MEH  JOY
# 4                  DESPAIR  ...   DESPAIR  JOY
#
#   Vials Of Pure High Fructose Corn Syrup, For Main-Lining Into Your Vein  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                                MEH
#
#    Vicodin Whatchamacallit Bars White Bread Whole Wheat Anything  \
# 0      NaN                  NaN         NaN                  NaN
# 1  DESPAIR              DESPAIR     DESPAIR              DESPAIR
# 2      NaN                  NaN         NaN                  NaN
# 3      JOY                  JOY     DESPAIR              DESPAIR
# 4      JOY                  JOY     DESPAIR              DESPAIR
#
#   York Peppermint Patties           Dress     Day
# 0                     NaN             NaN     NaN
# 1                 DESPAIR  White and gold  Sunday
# 2                     NaN             NaN     NaN
# 3                 DESPAIR  White and gold  Sunday
# 4                     JOY  White and gold  Friday
#
# [5 rows x 109 columns]

# %%
#Check shape after removing columns
candy.shape
# Out:
# (2460, 109)

# %% [markdown]
# ### 5 - Clean `going out` column

# %%
#Used value_counts() to check for any inconsistent data in the column.
candy['Going Out?'].value_counts()
# Out:
# No     2038
# Yes     312
# Name: Going Out?, dtype: int64

# %%
#Data is consistent, so the column is ready to be converted to categorical type.
candy['Going Out?']=candy['Going Out?'].astype('category')

# %%
#Replaced missing values with the mode.
candy['Going Out?'].fillna(candy['Going Out?'].mode()[0],inplace = True)

# %%
#Making sure the column has no more missing values.
candy['Going Out?'].isna().sum()
# Out:
#   Going Out? Gender  Age Country 100 Grand Bar  \
# 0         No    NaN  NaN     NaN           NaN
# 1         No   Male   44    USA            MEH
# 2         No   Male   49     USA           NaN
# 3         No   Male   40      us           MEH
# 4         No   Male   23     usa           JOY
#
#   Anonymous Brown Globs That Come In Black And Orange Wrappers\t(A.K.A. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any Full-Sized Candy Bar Black Jacks Bonkers (The Candy)  \
# 0                      NaN         NaN                 NaN
# 1                      JOY         MEH             DESPAIR
# 2                      NaN         NaN                 NaN
# 3                      JOY         MEH                 MEH
# 4                      JOY     DESPAIR                 MEH
#
#   Bonkers (The Board Game)  ... Trail Mix Twix  \
# 0                      NaN  ...       NaN  NaN
# 1                  DESPAIR  ...   DESPAIR  JOY
# 2                      NaN  ...       NaN  NaN
# 3                  DESPAIR  ...       MEH  JOY
# 4                  DESPAIR  ...   DESPAIR  JOY
#
#   Vials Of Pure High Fructose Corn Syrup, For Main-Lining Into Your Vein  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                                MEH
#
#    Vicodin Whatchamacallit Bars White Bread Whole Wheat Anything  \
# 0      NaN                  NaN         NaN                  NaN
# 1  DESPAIR              DESPAIR     DESPAIR              DESPAIR
# 2      NaN                  NaN         NaN                  NaN
# 3      JOY                  JOY     DESPAIR              DESPAIR
# 4      JOY                  JOY     DESPAIR              DESPAIR
#
#   York Peppermint Patties           Dress     Day
# 0                     NaN             NaN     NaN
# 1                 DESPAIR  White and gold  Sunday
# 2                     NaN             NaN     NaN
# 3                 DESPAIR  White and gold  Sunday
# 4                     JOY  White and gold  Friday
#
# [5 rows x 109 columns]

# %% [markdown]
# ### 6 - Clean ` gender` column

# %%
#Used value_counts() to check for any inconsistent data in the column.
candy['Gender'].value_counts()
# Out:
# Male                  1467
# Female                 839
# I'd rather not say      83
# Other                   30
# Name: Gender, dtype: int64

# %%
#Data is consistent.
#People may have not wanted to say their gender, so we could replace the Nan with 'I'd rather not say'.
candy['Gender']=candy['Gender'].astype('category')
candy['Gender'].fillna('I\'d rather not say',inplace = True)
candy['Gender'].isna().sum()
# Out:
#   Going Out?              Gender  Age Country 100 Grand Bar  \
# 0         No  I'd rather not say  NaN     NaN           NaN
# 1         No                Male   44    USA            MEH
# 2         No                Male   49     USA           NaN
# 3         No                Male   40      us           MEH
# 4         No                Male   23     usa           JOY
#
#   Anonymous Brown Globs That Come In Black And Orange Wrappers\t(A.K.A. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any Full-Sized Candy Bar Black Jacks Bonkers (The Candy)  \
# 0                      NaN         NaN                 NaN
# 1                      JOY         MEH             DESPAIR
# 2                      NaN         NaN                 NaN
# 3                      JOY         MEH                 MEH
# 4                      JOY     DESPAIR                 MEH
#
#   Bonkers (The Board Game)  ... Trail Mix Twix  \
# 0                      NaN  ...       NaN  NaN
# 1                  DESPAIR  ...   DESPAIR  JOY
# 2                      NaN  ...       NaN  NaN
# 3                  DESPAIR  ...       MEH  JOY
# 4                  DESPAIR  ...   DESPAIR  JOY
#
#   Vials Of Pure High Fructose Corn Syrup, For Main-Lining Into Your Vein  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                                MEH
#
#    Vicodin Whatchamacallit Bars White Bread Whole Wheat Anything  \
# 0      NaN                  NaN         NaN                  NaN
# 1  DESPAIR              DESPAIR     DESPAIR              DESPAIR
# 2      NaN                  NaN         NaN                  NaN
# 3      JOY                  JOY     DESPAIR              DESPAIR
# 4      JOY                  JOY     DESPAIR              DESPAIR
#
#   York Peppermint Patties           Dress     Day
# 0                     NaN             NaN     NaN
# 1                 DESPAIR  White and gold  Sunday
# 2                     NaN             NaN     NaN
# 3                 DESPAIR  White and gold  Sunday
# 4                     JOY  White and gold  Friday
#
# [5 rows x 109 columns]

# %% [markdown]
# ### 7 - Clean ` age` column

# %%
#Check for inconsistent data.
candy['Age'].value_counts()
# Out:
# 40                                                  92
# 34                                                  90
# 37                                                  89
# 43                                                  86
# 42                                                  79
# 36                                                  79
# 35                                                  77
# 44                                                  76
# 38                                                  76
# 45                                                  75
# 33                                                  75
# 41                                                  74
# 50                                                  71
# 39                                                  69
# 49                                                  69
# 32                                                  68
# 48                                                  64
# 47                                                  63
# 30                                                  62
# 53                                                  57
# 46                                                  55
# 52                                                  50
# 56                                                  46
# 27                                                  45
# 31                                                  45
# 51                                                  41
# 28                                                  37
# 54                                                  36
# 58                                                  34
# 55                                                  32
# 60                                                  31
# 29                                                  27
# 57                                                  25
# 59                                                  24
# 26                                                  23
# 61                                                  20
# 62                                                  20
# 63                                                  20
# 25                                                  19
# 64                                                  17
# 24                                                  16
# 21                                                  14
# 65                                                  13
# 20                                                  12
# 22                                                  11
# 18                                                  10
# 66                                                   9
# 12                                                   9
# 23                                                   9
# 70                                                   8
# 68                                                   8
# 15                                                   8
# 11                                                   7
# 13                                                   6
# 71                                                   6
# 67                                                   6
# 72                                                   6
# 69                                                   5
# 17                                                   5
# 9                                                    4
# 16                                                   4
# 73                                                   4
# 10                                                   3
# 19                                                   3
# 75                                                   3
# 8                                                    2
# 7                                                    2
# 14                                                   2
# old                                                  2
# 76                                                   2
# 100                                                  2
# 90                                                   2
# 6                                                    2
# your mom                                             1
# I can remember when Java was a cool new language     1
# 1000                                                 1
# sixty-nine                                           1
# 46 Halloweens.                                       1
# ancient                                              1
# MY NAME JEFF                                         1
# old enough                                           1
# 1                                                    1
# 77                                                   1
# OLD                                                  1
# 4                                                    1
# 70.5                                                 1
# 59 on the day after Halloween                        1
# 312                                                  1
# Over 50                                              1
# 24-50                                                1
# Old enough                                           1
# Many                                                 1
# ?                                                    1
# no                                                   1
# 45-55                                                1
# 99                                                   1
# hahahahaha                                           1
# 88                                                   1
# 39.4                                                 1
# 74                                                   1
# 102                                                  1
# older than dirt                                      1
# 5u                                                   1
# Enough                                               1
# See question 2                                       1
# 60+                                                  1
# Name: Age, dtype: int64

# %%
#Alot of inconsistencies are present,especially string sentences which need to be removed.
candy['Age'] = pd.to_numeric(candy['Age'],errors = 'coerce')
candy['Age'].value_counts()
# Out:
# 40.0      92
# 34.0      90
# 37.0      89
# 43.0      86
# 42.0      79
# 36.0      79
# 35.0      77
# 38.0      76
# 44.0      76
# 45.0      75
# 33.0      75
# 41.0      74
# 50.0      71
# 39.0      69
# 49.0      69
# 32.0      68
# 48.0      64
# 47.0      63
# 30.0      62
# 53.0      57
# 46.0      55
# 52.0      50
# 56.0      46
# 27.0      45
# 31.0      45
# 51.0      41
# 28.0      37
# 54.0      36
# 58.0      34
# 55.0      32
# 60.0      31
# 29.0      27
# 57.0      25
# 59.0      24
# 26.0      23
# 62.0      20
# 61.0      20
# 63.0      20
# 25.0      19
# 64.0      17
# 24.0      16
# 21.0      14
# 65.0      13
# 20.0      12
# 22.0      11
# 18.0      10
# 23.0       9
# 12.0       9
# 66.0       9
# 70.0       8
# 68.0       8
# 15.0       8
# 11.0       7
# 72.0       6
# 67.0       6
# 71.0       6
# 13.0       6
# 17.0       5
# 69.0       5
# 73.0       4
# 16.0       4
# 9.0        4
# 75.0       3
# 10.0       3
# 19.0       3
# 6.0        2
# 76.0       2
# 90.0       2
# 8.0        2
# 7.0        2
# 14.0       2
# 100.0      2
# 1.0        1
# 70.5       1
# 77.0       1
# 1000.0     1
# 99.0       1
# 312.0      1
# 102.0      1
# 74.0       1
# 39.4       1
# 88.0       1
# 4.0        1
# Name: Age, dtype: int64

# %%
#Now that strings are removed, time to handle the outliers
candy.loc[candy['Age'] < 10,'Age'] = None
candy.loc[candy['Age'] > 80,'Age'] = None
candy['Age'].unique()
# Out:
# array([ nan, 44. , 49. , 40. , 23. , 53. , 33. , 43. , 56. , 64. , 37. ,
#        59. , 48. , 54. , 36. , 45. , 25. , 34. , 35. , 38. , 58. , 50. ,
#        47. , 16. , 52. , 63. , 65. , 41. , 27. , 31. , 61. , 46. , 42. ,
#        62. , 29. , 39. , 32. , 28. , 69. , 67. , 30. , 22. , 26. , 51. ,
#        70. , 24. , 18. , 19. , 57. , 60. , 66. , 12. , 55. , 72. , 21. ,
#        11. , 68. , 20. , 10. , 71. , 13. , 39.4, 74. , 17. , 15. , 75. ,
#        14. , 76. , 77. , 73. , 70.5])

# %%
#Now to replace missing values with the mean of the ages
mean_age = candy['Age'].mean()
candy['Age'].fillna(mean_age,inplace=True)

# %%
#Change datatype to integer because it looks better :)
candy['Age'] = candy['Age'].astype(int)
# Out:
#   Going Out?              Gender  Age Country 100 Grand Bar  \
# 0         No  I'd rather not say   42     NaN           NaN
# 1         No                Male   44    USA            MEH
# 2         No                Male   49     USA           NaN
# 3         No                Male   40      us           MEH
# 4         No                Male   23     usa           JOY
#
#   Anonymous Brown Globs That Come In Black And Orange Wrappers\t(A.K.A. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any Full-Sized Candy Bar Black Jacks Bonkers (The Candy)  \
# 0                      NaN         NaN                 NaN
# 1                      JOY         MEH             DESPAIR
# 2                      NaN         NaN                 NaN
# 3                      JOY         MEH                 MEH
# 4                      JOY     DESPAIR                 MEH
#
#   Bonkers (The Board Game)  ... Trail Mix Twix  \
# 0                      NaN  ...       NaN  NaN
# 1                  DESPAIR  ...   DESPAIR  JOY
# 2                      NaN  ...       NaN  NaN
# 3                  DESPAIR  ...       MEH  JOY
# 4                  DESPAIR  ...   DESPAIR  JOY
#
#   Vials Of Pure High Fructose Corn Syrup, For Main-Lining Into Your Vein  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                                MEH
#
#    Vicodin Whatchamacallit Bars White Bread Whole Wheat Anything  \
# 0      NaN                  NaN         NaN                  NaN
# 1  DESPAIR              DESPAIR     DESPAIR              DESPAIR
# 2      NaN                  NaN         NaN                  NaN
# 3      JOY                  JOY     DESPAIR              DESPAIR
# 4      JOY                  JOY     DESPAIR              DESPAIR
#
#   York Peppermint Patties           Dress     Day
# 0                     NaN             NaN     NaN
# 1                 DESPAIR  White and gold  Sunday
# 2                     NaN             NaN     NaN
# 3                 DESPAIR  White and gold  Sunday
# 4                     JOY  White and gold  Friday
#
# [5 rows x 109 columns]

# %% [markdown]
# ### 8 - Clean ` country` column

# %%
#Check for inconsistent values
candy['Country'].value_counts()
# Out:
# USA                                                                     699
# United States                                                           497
# usa                                                                     217
# Canada                                                                  179
# Usa                                                                     139
# US                                                                      126
# USA                                                                      73
# United States of America                                                 57
# us                                                                       40
# united states                                                            38
# United States                                                            37
# canada                                                                   34
# United states                                                            19
# Us                                                                       16
# United Kingdom                                                           13
# UK                                                                       13
# United States of America                                                 11
# U.S.                                                                      8
# Canada                                                                    8
# Germany                                                                   7
# U.S.A.                                                                    7
# Netherlands                                                               6
# Japan                                                                     5
# Australia                                                                 5
# united states of america                                                  5
# Unites States                                                             4
# america                                                                   4
# Mexico                                                                    4
# Scotland                                                                  4
# US of A                                                                   4
# u.s.                                                                      3
# Ireland                                                                   3
# germany                                                                   3
# Switzerland                                                               3
# CANADA                                                                    2
# America                                                                   2
# United State                                                              2
# China                                                                     2
# australia                                                                 2
# Uk                                                                        2
# Sweden                                                                    2
# United Stated                                                             2
# The United States                                                         2
# uk                                                                        2
# Denmark                                                                   2
# New Jersey                                                                1
# South Korea                                                               1
# Scotland                                                                  1
# Indonesia                                                                 1
# United ststes                                                             1
# Atlantis                                                                  1
# UD                                                                        1
# Ahem....Amerca                                                            1
# France                                                                    1
# The Netherlands                                                           1
# United Statss                                                             1
# endland                                                                   1
# hong kong                                                                 1
# murrika                                                                   1
# USA! USA! USA!                                                            1
# I don't know anymore                                                      1
# USA USA USA!!!!                                                           1
# United kingdom                                                            1
# subscribe to dm4uz3 on youtube                                            1
# 1                                                                         1
# united ststes                                                             1
# United Statea                                                             1
# u s a                                                                     1
# Narnia                                                                    1
# U.S.                                                                      1
# Hong Kong                                                                 1
# spain                                                                     1
# Ireland                                                                   1
# Taiwan                                                                    1
# USSA                                                                      1
# Singapore                                                                 1
# N. America                                                                1
# soviet canuckistan                                                        1
# united States                                                             1
# Alaska                                                                    1
# USAA                                                                      1
# UK                                                                        1
# A                                                                         1
# Canada`                                                                   1
# 46                                                                        1
# The United States of America                                              1
# Costa Rica                                                                1
# U.K.                                                                      1
# U S                                                                       1
# Earth                                                                     1
# Europe                                                                    1
# Unied States                                                              1
# North Carolina                                                            1
# unhinged states                                                           1
# finland                                                                   1
# france                                                                    1
# 35                                                                        1
# USAUSAUSA                                                                 1
# u.s.a.                                                                    1
# canada                                                                    1
# England                                                                   1
# UAE                                                                       1
# United staes                                                              1
# Murica                                                                    1
# unite states                                                              1
# cascadia                                                                  1
# Iceland                                                                   1
# insanity lately                                                           1
# Usa                                                                       1
# I pretend to be from Canada, but I am really from the United States.      1
# South africa                                                              1
# USa                                                                       1
# California                                                                1
# Korea                                                                     1
# United Sates                                                              1
# Trumpistan                                                                1
# New York                                                                  1
# Canae                                                                     1
# Can                                                                       1
# France                                                                    1
# 32                                                                        1
# 45                                                                        1
# Pittsburgh                                                                1
# usas                                                                      1
# 'merica                                                                   1
# USA? Hard to tell anymore..                                               1
# Greece                                                                    1
# Fear and Loathing                                                         1
# Name: Country, dtype: int64

# %%
#Lots of inconsistencies are present due to free text, so we can use fuzzywuzzy to substitute them with the correct values.

#First I create a list with the correct countries.
countries = ['USA','UK','United States of America','America','Canada','United Kingdom England','Germany','Netherlands','Japan','Australia','Mexico','Scotland','Ireland','Switzerland','China','Sweden','Denmark','South Korea','Indonesia','France','England','Spain','Taiwan','Singapore','Costa Rica','Finland','United Arab Emirates','Iceland','Cascadia','Hong Kong','South Africa','Greece']
#Now to loop through the column and assign close matches to the correct country
for country in countries:
    matches = process.extract(country,candy['Country'],limit = candy.shape[0])
    for potential_match in matches:
        if potential_match[1] >= 80:
            candy.loc[candy['Country'] == potential_match[0],'Country'] = country

# %%
candy['Country'].value_counts()
# Out:
# USA                               1319
# America                            726
# Canada                             226
# UK                                  19
# Germany                             10
# U.S.A.                               7
# Australia                            7
# Netherlands                          7
# Iceland                              5
# Scotland                             5
# Japan                                5
# Mexico                               4
# France                               3
# Switzerland                          3
# China                                2
# Denmark                              2
# South Korea                          2
# England                              2
# Hong Kong                            2
# Sweden                               2
# Taiwan                               1
# Singapore                            1
# Spain                                1
# soviet canuckistan                   1
# Narnia                               1
# murrika                              1
# Atlantis                             1
# Indonesia                            1
# New Jersey                           1
# UD                                   1
# subscribe to dm4uz3 on youtube       1
# 1                                    1
# I don't know anymore                 1
# u s a                                1
# Alaska                               1
# New York                             1
# South Africa                         1
# California                           1
# Murica                               1
# UAE                                  1
# u.s.a.                               1
# 35                                   1
# Finland                              1
# North Carolina                       1
# Europe                               1
# Earth                                1
# Costa Rica                           1
# 46                                   1
# Cascadia                             1
# insanity lately                      1
# Greece                               1
# USA? Hard to tell anymore..          1
# Pittsburgh                           1
# 45                                   1
# 32                                   1
# Canae                                1
# Trumpistan                           1
# Fear and Loathing                    1
# Name: Country, dtype: int64

# %%
#Now to remove everything that is not a valid country.
candy['Country'].loc[candy['Country'].isin(countries) == False] = None
candy['Country'].isna().sum()
# Out:
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2973270942.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candy['Country'].loc[candy['Country'].isin(countries) == False] = None
# 100

# %%
#Now to replace missing values with mode.
candy['Country'].fillna(candy['Country'].mode()[0],inplace = True)
candy['Country'].isna().sum()
candy['Country'] = candy['Country'].astype(str)

# %% [markdown]
# ### 10 - Clean ` Q6` columns

# %%
#Separated all the candy columns in a different dataframe for easier cleaning.
candies = candy.iloc[:,4:107]
candies.head()
# Out:
#   100 Grand Bar  \
# 0           NaN
# 1           MEH
# 2           NaN
# 3           MEH
# 4           JOY
#
#   Anonymous Brown Globs That Come In Black And Orange Wrappers\t(A.K.A. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any Full-Sized Candy Bar Black Jacks Bonkers (The Candy)  \
# 0                      NaN         NaN                 NaN
# 1                      JOY         MEH             DESPAIR
# 2                      NaN         NaN                 NaN
# 3                      JOY         MEH                 MEH
# 4                      JOY     DESPAIR                 MEH
#
#   Bonkers (The Board Game) Bottle Caps Box'O'Raisins Broken Glow Stick  \
# 0                      NaN         NaN           NaN               NaN
# 1                  DESPAIR     DESPAIR       DESPAIR           DESPAIR
# 2                      NaN         NaN           NaN               NaN
# 3                  DESPAIR         MEH       DESPAIR           DESPAIR
# 4                  DESPAIR         MEH       DESPAIR           DESPAIR
#
#   Butterfinger  ... Three Musketeers Tolberone Something Or Other Trail Mix  \
# 0          NaN  ...              NaN                          NaN       NaN
# 1      DESPAIR  ...              JOY                          JOY   DESPAIR
# 2          NaN  ...              NaN                          NaN       NaN
# 3          MEH  ...          DESPAIR                          JOY       MEH
# 4          MEH  ...              JOY                          JOY   DESPAIR
#
#   Twix Vials Of Pure High Fructose Corn Syrup, For Main-Lining Into Your Vein  \
# 0  NaN                                                NaN
# 1  JOY                                            DESPAIR
# 2  NaN                                                NaN
# 3  JOY                                            DESPAIR
# 4  JOY                                                MEH
#
#    Vicodin Whatchamacallit Bars White Bread Whole Wheat Anything  \
# 0      NaN                  NaN         NaN                  NaN
# 1  DESPAIR              DESPAIR     DESPAIR              DESPAIR
# 2      NaN                  NaN         NaN                  NaN
# 3      JOY                  JOY     DESPAIR              DESPAIR
# 4      JOY                  JOY     DESPAIR              DESPAIR
#
#   York Peppermint Patties
# 0                     NaN
# 1                 DESPAIR
# 2                     NaN
# 3                 DESPAIR
# 4                     JOY
#
# [5 rows x 103 columns]

# %%
#Used for loop on all the columns to apply the cleaning methods.
#People may have not known the candy or tried it before.
#So we can replace Nan with 'Unknown'
categories = ['JOY','DESPAIR','MEH','UNKNOWN']
for column in candies.columns:
    candies[column] = candies[column].astype(str)
    candies[column].loc[candies[column].isin(categories) == False] = None
    candies[column].fillna('UNKNOWN',inplace=True)
    candies[column] = candies[column].astype('category')
candies.isna().sum()
# Out:
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# C:\Users\mancr\AppData\Local\Temp\ipykernel_18868\2479647798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candies[column].loc[candies[column].isin(categories) == False] = None
# 100 Grand Bar                                                                        0
# Anonymous Brown Globs That Come In Black And Orange Wrappers\t(A.K.A. Mary Janes)    0
# Any Full-Sized Candy Bar                                                             0
# Black Jacks                                                                          0
# Bonkers (The Candy)                                                                  0
# Bonkers (The Board Game)                                                             0
# Bottle Caps                                                                          0
# Box'O'Raisins                                                                        0
# Broken Glow Stick                                                                    0
# Butterfinger                                                                         0
# Cadbury Creme Eggs                                                                   0
# Candy Corn                                                                           0
# Candy That Is Clearly Just The Stuff Given Out For Free At Restaurants               0
# Caramellos                                                                           0
# Cash, Or Other Forms Of Legal Tender                                                 0
# Chardonnay                                                                           0
# Chick-O-Sticks (We Don’T Know What That Is)                                          0
# Chiclets                                                                             0
# Coffee Crisp                                                                         0
# Creepy Religious Comics/Chick Tracts                                                 0
# Dental Paraphenalia                                                                  0
# Dots                                                                                 0
# Dove Bars                                                                            0
# Fuzzy Peaches                                                                        0
# Generic Brand Acetaminophen                                                          0
# Glow Sticks                                                                          0
# Goo Goo Clusters                                                                     0
# Good N' Plenty                                                                       0
# Gum From Baseball Cards                                                              0
# Gummy Bears Straight Up                                                              0
# Hard Candy                                                                           0
# Healthy Fruit                                                                        0
# Heath Bar                                                                            0
# Hershey'S Dark Chocolate                                                             0
# Hershey’S Milk Chocolate                                                             0
# Hershey'S Kisses                                                                     0
# Hugs (Actual Physical Hugs)                                                          0
# Jolly Rancher (Bad Flavor)                                                           0
# Jolly Ranchers (Good Flavor)                                                         0
# Joyjoy (Mit Iodine!)                                                                 0
# Junior Mints                                                                         0
# Senior Mints                                                                         0
# Kale Smoothie                                                                        0
# Kinder Happy Hippo                                                                   0
# Kit Kat                                                                              0
# Laffytaffy                                                                           0
# Lemonheads                                                                           0
# Licorice (Not Black)                                                                 0
# Licorice (Yes Black)                                                                 0
# Lindt Truffle                                                                        0
# Lollipops                                                                            0
# Mars                                                                                 0
# Maynards                                                                             0
# Mike And Ike                                                                         0
# Milk Duds                                                                            0
# Milky Way                                                                            0
# Regular M&Ms                                                                         0
# Peanut M&M’S                                                                         0
# Blue M&M'S                                                                           0
# Red M&M'S                                                                            0
# Green Party M&M'S                                                                    0
# Independent M&M'S                                                                    0
# Abstained From M&M'Ing.                                                              0
# Minibags Of Chips                                                                    0
# Mint Kisses                                                                          0
# Mint Juleps                                                                          0
# Mr. Goodbar                                                                          0
# Necco Wafers                                                                         0
# Nerds                                                                                0
# Nestle Crunch                                                                        0
# Now'N'Laters                                                                         0
# Peeps                                                                                0
# Pencils                                                                              0
# Pixy Stix                                                                            0
# Real Housewives Of Orange County Season 9 Blue-Ray                                   0
# Reese’S Peanut Butter Cups                                                           0
# Reese'S Pieces                                                                       0
# Reggie Jackson Bar                                                                   0
# Rolos                                                                                0
# Sandwich-Sized Bags Filled With Booberry Crunch                                      0
# Skittles                                                                             0
# Smarties (American)                                                                  0
# Smarties (Commonwealth)                                                              0
# Snickers                                                                             0
# Sourpatch Kids (I.E. Abominations Of Nature)                                         0
# Spotted Dick                                                                         0
# Starburst                                                                            0
# Sweet Tarts                                                                          0
# Swedish Fish                                                                         0
# Sweetums (A Friend To Diabetes)                                                      0
# Take 5                                                                               0
# Tic Tacs                                                                             0
# Those Odd Marshmallow Circus Peanut Things                                           0
# Three Musketeers                                                                     0
# Tolberone Something Or Other                                                         0
# Trail Mix                                                                            0
# Twix                                                                                 0
# Vials Of Pure High Fructose Corn Syrup, For Main-Lining Into Your Vein               0
# Vicodin                                                                              0
# Whatchamacallit Bars                                                                 0
# White Bread                                                                          0
# Whole Wheat Anything                                                                 0
# York Peppermint Patties                                                              0
# dtype: int64

# %%
#Now to replace the dirty columns in the original dataframe with the new clean columns. 
candy.iloc[:,4:107] = candies
candy.head()
# Out:
#   Going Out?              Gender  Age Country 100 Grand Bar  \
# 0         No  I'd rather not say   42     USA       UNKNOWN
# 1         No                Male   44     USA           MEH
# 2         No                Male   49     USA       UNKNOWN
# 3         No                Male   40     USA           MEH
# 4         No                Male   23     USA           JOY
#
#   Anonymous Brown Globs That Come In Black And Orange Wrappers\t(A.K.A. Mary Janes)  \
# 0                                            UNKNOWN
# 1                                            DESPAIR
# 2                                            UNKNOWN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any Full-Sized Candy Bar Black Jacks Bonkers (The Candy)  \
# 0                  UNKNOWN     UNKNOWN             UNKNOWN
# 1                      JOY         MEH             DESPAIR
# 2                  UNKNOWN     UNKNOWN             UNKNOWN
# 3                      JOY         MEH                 MEH
# 4                      JOY     DESPAIR                 MEH
#
#   Bonkers (The Board Game)  ... Trail Mix     Twix  \
# 0                  UNKNOWN  ...   UNKNOWN  UNKNOWN
# 1                  DESPAIR  ...   DESPAIR      JOY
# 2                  UNKNOWN  ...   UNKNOWN  UNKNOWN
# 3                  DESPAIR  ...       MEH      JOY
# 4                  DESPAIR  ...   DESPAIR      JOY
#
#   Vials Of Pure High Fructose Corn Syrup, For Main-Lining Into Your Vein  \
# 0                                            UNKNOWN
# 1                                            DESPAIR
# 2                                            UNKNOWN
# 3                                            DESPAIR
# 4                                                MEH
#
#    Vicodin Whatchamacallit Bars White Bread Whole Wheat Anything  \
# 0  UNKNOWN              UNKNOWN     UNKNOWN              UNKNOWN
# 1  DESPAIR              DESPAIR     DESPAIR              DESPAIR
# 2  UNKNOWN              UNKNOWN     UNKNOWN              UNKNOWN
# 3      JOY                  JOY     DESPAIR              DESPAIR
# 4      JOY                  JOY     DESPAIR              DESPAIR
#
#   York Peppermint Patties           Dress     Day
# 0                 UNKNOWN             NaN     NaN
# 1                 DESPAIR  White and gold  Sunday
# 2                 UNKNOWN             NaN     NaN
# 3                 DESPAIR  White and gold  Sunday
# 4                     JOY  White and gold  Friday
#
# [5 rows x 109 columns]

# %% [markdown]
# ### 11 - Clean ` dress` column

# %%
#Check for inconsistent data.
candy['Dress'].value_counts()
# Out:
# White and gold    1081
# Blue and black     635
# Name: Dress, dtype: int64

# %%
#Data is consistent, now to handle the missing values the same way as the previous categorical columns
candy['Dress']=candy['Dress'].astype('category')
candy['Dress'].fillna(candy['Dress'].mode()[0],inplace = True)
candy['Dress'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### 12 - Clean ` day` column

# %%
#Same process as the Dress column.
candy['Day'].value_counts()
# Out:
# Friday    1091
# Sunday     644
# Name: Day, dtype: int64

# %%
candy['Day']=candy['Day'].astype('category')
candy['Day'].fillna(candy['Day'].mode()[0],inplace = True)
candy['Day'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### 13 - Check

# %%
candy.dtypes
# Out:
# Going Out?                                                                           category
# Gender                                                                               category
# Age                                                                                     int32
# Country                                                                                object
# 100 Grand Bar                                                                        category
# Anonymous Brown Globs That Come In Black And Orange Wrappers\t(A.K.A. Mary Janes)    category
# Any Full-Sized Candy Bar                                                             category
# Black Jacks                                                                          category
# Bonkers (The Candy)                                                                  category
# Bonkers (The Board Game)                                                             category
# Bottle Caps                                                                          category
# Box'O'Raisins                                                                        category
# Broken Glow Stick                                                                    category
# Butterfinger                                                                         category
# Cadbury Creme Eggs                                                                   category
# Candy Corn                                                                           category
# Candy That Is Clearly Just The Stuff Given Out For Free At Restaurants               category
# Caramellos                                                                           category
# Cash, Or Other Forms Of Legal Tender                                                 category
# Chardonnay                                                                           category
# Chick-O-Sticks (We Don’T Know What That Is)                                          category
# Chiclets                                                                             category
# Coffee Crisp                                                                         category
# Creepy Religious Comics/Chick Tracts                                                 category
# Dental Paraphenalia                                                                  category
# Dots                                                                                 category
# Dove Bars                                                                            category
# Fuzzy Peaches                                                                        category
# Generic Brand Acetaminophen                                                          category
# Glow Sticks                                                                          category
# Goo Goo Clusters                                                                     category
# Good N' Plenty                                                                       category
# Gum From Baseball Cards                                                              category
# Gummy Bears Straight Up                                                              category
# Hard Candy                                                                           category
# Healthy Fruit                                                                        category
# Heath Bar                                                                            category
# Hershey'S Dark Chocolate                                                             category
# Hershey’S Milk Chocolate                                                             category
# Hershey'S Kisses                                                                     category
# Hugs (Actual Physical Hugs)                                                          category
# Jolly Rancher (Bad Flavor)                                                           category
# Jolly Ranchers (Good Flavor)                                                         category
# Joyjoy (Mit Iodine!)                                                                 category
# Junior Mints                                                                         category
# Senior Mints                                                                         category
# Kale Smoothie                                                                        category
# Kinder Happy Hippo                                                                   category
# Kit Kat                                                                              category
# Laffytaffy                                                                           category
# Lemonheads                                                                           category
# Licorice (Not Black)                                                                 category
# Licorice (Yes Black)                                                                 category
# Lindt Truffle                                                                        category
# Lollipops                                                                            category
# Mars                                                                                 category
# Maynards                                                                             category
# Mike And Ike                                                                         category
# Milk Duds                                                                            category
# Milky Way                                                                            category
# Regular M&Ms                                                                         category
# Peanut M&M’S                                                                         category
# Blue M&M'S                                                                           category
# Red M&M'S                                                                            category
# Green Party M&M'S                                                                    category
# Independent M&M'S                                                                    category
# Abstained From M&M'Ing.                                                              category
# Minibags Of Chips                                                                    category
# Mint Kisses                                                                          category
# Mint Juleps                                                                          category
# Mr. Goodbar                                                                          category
# Necco Wafers                                                                         category
# Nerds                                                                                category
# Nestle Crunch                                                                        category
# Now'N'Laters                                                                         category
# Peeps                                                                                category
# Pencils                                                                              category
# Pixy Stix                                                                            category
# Real Housewives Of Orange County Season 9 Blue-Ray                                   category
# Reese’S Peanut Butter Cups                                                           category
# Reese'S Pieces                                                                       category
# Reggie Jackson Bar                                                                   category
# Rolos                                                                                category
# Sandwich-Sized Bags Filled With Booberry Crunch                                      category
# Skittles                                                                             category
# Smarties (American)                                                                  category
# Smarties (Commonwealth)                                                              category
# Snickers                                                                             category
# Sourpatch Kids (I.E. Abominations Of Nature)                                         category
# Spotted Dick                                                                         category
# Starburst                                                                            category
# Sweet Tarts                                                                          category
# Swedish Fish                                                                         category
# Sweetums (A Friend To Diabetes)                                                      category
# Take 5                                                                               category
# Tic Tacs                                                                             category
# Those Odd Marshmallow Circus Peanut Things                                           category
# Three Musketeers                                                                     category
# Tolberone Something Or Other                                                         category
# Trail Mix                                                                            category
# Twix                                                                                 category
# Vials Of Pure High Fructose Corn Syrup, For Main-Lining Into Your Vein               category
# Vicodin                                                                              category
# Whatchamacallit Bars                                                                 category
# White Bread                                                                          category
# Whole Wheat Anything                                                                 category
# York Peppermint Patties                                                              category
# Dress                                                                                category
# Day                                                                                  category
# dtype: object

# %%
candy.shape
# Out:
# (2460, 109)

# %%
candy.isna().sum()
# Out:
# Going Out?                                                                           0
# Gender                                                                               0
# Age                                                                                  0
# Country                                                                              0
# 100 Grand Bar                                                                        0
# Anonymous Brown Globs That Come In Black And Orange Wrappers\t(A.K.A. Mary Janes)    0
# Any Full-Sized Candy Bar                                                             0
# Black Jacks                                                                          0
# Bonkers (The Candy)                                                                  0
# Bonkers (The Board Game)                                                             0
# Bottle Caps                                                                          0
# Box'O'Raisins                                                                        0
# Broken Glow Stick                                                                    0
# Butterfinger                                                                         0
# Cadbury Creme Eggs                                                                   0
# Candy Corn                                                                           0
# Candy That Is Clearly Just The Stuff Given Out For Free At Restaurants               0
# Caramellos                                                                           0
# Cash, Or Other Forms Of Legal Tender                                                 0
# Chardonnay                                                                           0
# Chick-O-Sticks (We Don’T Know What That Is)                                          0
# Chiclets                                                                             0
# Coffee Crisp                                                                         0
# Creepy Religious Comics/Chick Tracts                                                 0
# Dental Paraphenalia                                                                  0
# Dots                                                                                 0
# Dove Bars                                                                            0
# Fuzzy Peaches                                                                        0
# Generic Brand Acetaminophen                                                          0
# Glow Sticks                                                                          0
# Goo Goo Clusters                                                                     0
# Good N' Plenty                                                                       0
# Gum From Baseball Cards                                                              0
# Gummy Bears Straight Up                                                              0
# Hard Candy                                                                           0
# Healthy Fruit                                                                        0
# Heath Bar                                                                            0
# Hershey'S Dark Chocolate                                                             0
# Hershey’S Milk Chocolate                                                             0
# Hershey'S Kisses                                                                     0
# Hugs (Actual Physical Hugs)                                                          0
# Jolly Rancher (Bad Flavor)                                                           0
# Jolly Ranchers (Good Flavor)                                                         0
# Joyjoy (Mit Iodine!)                                                                 0
# Junior Mints                                                                         0
# Senior Mints                                                                         0
# Kale Smoothie                                                                        0
# Kinder Happy Hippo                                                                   0
# Kit Kat                                                                              0
# Laffytaffy                                                                           0
# Lemonheads                                                                           0
# Licorice (Not Black)                                                                 0
# Licorice (Yes Black)                                                                 0
# Lindt Truffle                                                                        0
# Lollipops                                                                            0
# Mars                                                                                 0
# Maynards                                                                             0
# Mike And Ike                                                                         0
# Milk Duds                                                                            0
# Milky Way                                                                            0
# Regular M&Ms                                                                         0
# Peanut M&M’S                                                                         0
# Blue M&M'S                                                                           0
# Red M&M'S                                                                            0
# Green Party M&M'S                                                                    0
# Independent M&M'S                                                                    0
# Abstained From M&M'Ing.                                                              0
# Minibags Of Chips                                                                    0
# Mint Kisses                                                                          0
# Mint Juleps                                                                          0
# Mr. Goodbar                                                                          0
# Necco Wafers                                                                         0
# Nerds                                                                                0
# Nestle Crunch                                                                        0
# Now'N'Laters                                                                         0
# Peeps                                                                                0
# Pencils                                                                              0
# Pixy Stix                                                                            0
# Real Housewives Of Orange County Season 9 Blue-Ray                                   0
# Reese’S Peanut Butter Cups                                                           0
# Reese'S Pieces                                                                       0
# Reggie Jackson Bar                                                                   0
# Rolos                                                                                0
# Sandwich-Sized Bags Filled With Booberry Crunch                                      0
# Skittles                                                                             0
# Smarties (American)                                                                  0
# Smarties (Commonwealth)                                                              0
# Snickers                                                                             0
# Sourpatch Kids (I.E. Abominations Of Nature)                                         0
# Spotted Dick                                                                         0
# Starburst                                                                            0
# Sweet Tarts                                                                          0
# Swedish Fish                                                                         0
# Sweetums (A Friend To Diabetes)                                                      0
# Take 5                                                                               0
# Tic Tacs                                                                             0
# Those Odd Marshmallow Circus Peanut Things                                           0
# Three Musketeers                                                                     0
# Tolberone Something Or Other                                                         0
# Trail Mix                                                                            0
# Twix                                                                                 0
# Vials Of Pure High Fructose Corn Syrup, For Main-Lining Into Your Vein               0
# Vicodin                                                                              0
# Whatchamacallit Bars                                                                 0
# White Bread                                                                          0
# Whole Wheat Anything                                                                 0
# York Peppermint Patties                                                              0
# Dress                                                                                0
# Day                                                                                  0
# dtype: int64

# %%
candy.head(10)
# Out:
#   Going Out?              Gender  Age Country 100 Grand Bar  \
# 0         No  I'd rather not say   42     USA       UNKNOWN
# 1         No                Male   44     USA           MEH
# 2         No                Male   49     USA       UNKNOWN
# 3         No                Male   40     USA           MEH
# 4         No                Male   23     USA           JOY
# 5         No                Male   42     USA           JOY
# 6         No                Male   53     USA       UNKNOWN
# 7         No                Male   33  Canada           JOY
# 8         No                Male   40  Canada           JOY
# 9         No              Female   53     USA           MEH
#
#   Anonymous Brown Globs That Come In Black And Orange Wrappers\t(A.K.A. Mary Janes)  \
# 0                                            UNKNOWN
# 1                                            DESPAIR
# 2                                            UNKNOWN
# 3                                            DESPAIR
# 4                                            DESPAIR
# 5                                            DESPAIR
# 6                                            UNKNOWN
# 7                                            DESPAIR
# 8                                            DESPAIR
# 9                                            DESPAIR
#
#   Any Full-Sized Candy Bar Black Jacks Bonkers (The Candy)  \
# 0                  UNKNOWN     UNKNOWN             UNKNOWN
# 1                      JOY         MEH             DESPAIR
# 2                  UNKNOWN     UNKNOWN             UNKNOWN
# 3                      JOY         MEH                 MEH
# 4                      JOY     DESPAIR                 MEH
# 5                      JOY     UNKNOWN             UNKNOWN
# 6                  UNKNOWN     UNKNOWN             UNKNOWN
# 7                      JOY     DESPAIR             DESPAIR
# 8                      JOY         MEH                 MEH
# 9                      JOY         MEH                 MEH
#
#   Bonkers (The Board Game)  ... Trail Mix     Twix  \
# 0                  UNKNOWN  ...   UNKNOWN  UNKNOWN
# 1                  DESPAIR  ...   DESPAIR      JOY
# 2                  UNKNOWN  ...   UNKNOWN  UNKNOWN
# 3                  DESPAIR  ...       MEH      JOY
# 4                  DESPAIR  ...   DESPAIR      JOY
# 5                  UNKNOWN  ...       MEH      JOY
# 6                  UNKNOWN  ...   UNKNOWN  UNKNOWN
# 7                      MEH  ...   DESPAIR      JOY
# 8                      MEH  ...   DESPAIR      JOY
# 9                      MEH  ...       MEH      JOY
#
#   Vials Of Pure High Fructose Corn Syrup, For Main-Lining Into Your Vein  \
# 0                                            UNKNOWN
# 1                                            DESPAIR
# 2                                            UNKNOWN
# 3                                            DESPAIR
# 4                                                MEH
# 5                                            DESPAIR
# 6                                            UNKNOWN
# 7                                                JOY
# 8                                                MEH
# 9                                            DESPAIR
#
#    Vicodin Whatchamacallit Bars White Bread Whole Wheat Anything  \
# 0  UNKNOWN              UNKNOWN     UNKNOWN              UNKNOWN
# 1  DESPAIR              DESPAIR     DESPAIR              DESPAIR
# 2  UNKNOWN              UNKNOWN     UNKNOWN              UNKNOWN
# 3      JOY                  JOY     DESPAIR              DESPAIR
# 4      JOY                  JOY     DESPAIR              DESPAIR
# 5  DESPAIR                  JOY     DESPAIR              DESPAIR
# 6  UNKNOWN              UNKNOWN     UNKNOWN              UNKNOWN
# 7      MEH              DESPAIR     DESPAIR              DESPAIR
# 8  DESPAIR                  MEH     DESPAIR              DESPAIR
# 9  DESPAIR                  MEH     DESPAIR              DESPAIR
#
#   York Peppermint Patties           Dress     Day
# 0                 UNKNOWN  White and gold  Friday
# 1                 DESPAIR  White and gold  Sunday
# 2                 UNKNOWN  White and gold  Friday
# 3                 DESPAIR  White and gold  Sunday
# 4                     JOY  White and gold  Friday
# 5                     JOY  White and gold  Friday
# 6                 UNKNOWN  White and gold  Friday
# 7                 DESPAIR  Blue and black  Friday
# 8                 DESPAIR  Blue and black  Sunday
# 9                     MEH  White and gold  Sunday
#
# [10 rows x 109 columns]

# %% [markdown]
# ### 14 - Cleaning steps summary
#
# -Removed columns with too much Nan as well as columns with no real value to the dataset in addition to the state/province column<br>   as it was very inconsistent due to free text input.<br>
# -Cleaned categorical columns by handling inconsistencies and replacing Nan values by either the mode or a third category.<br>
# -Cleaned Country column by using fuzzywuzzy to handle the incorrect inputs.<br>
# -Cleaned the only numeric column by handling removing string values and outliers, then replacing Nan values with the mean.<br>
